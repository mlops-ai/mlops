# %%
# !pip uninstall mlops-ai

# %%
import sys, os
sys.path.append('../..')

from mlops.tracking import set_active_experiment, set_active_project, create_project, create_experiment
from mlops.tracking import start_iteration
from mlops.monitoring import get_model_by_name, send_prediction

# %% [markdown]
# ## Setup Iteration with target model for monitoring

# %%
project = create_project(
    title="Project for monitoring", 
    description="Showcase project for monitoring :)",
    status='in_progress'
)
set_active_project(project_id=project['_id'])
# Out:
# 'Active project set to: 6556605c8621432f52372b98'

# %%
experiment = create_experiment(
    name="Iris modeling",
    description="Iris classification models"
)
set_active_experiment(experiment_id=experiment['id'])
# Out:
# 'Active experiment set to: 6556605c8621432f52372b99'

# %%
import pandas as pd 
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

url = 'https://raw.githubusercontent.com/TripathiAshutosh/dataset/main/iris.csv'
df = pd.read_csv(filepath_or_buffer=url, sep=',')
y = LabelEncoder().fit_transform(df['class'])
X = df.drop(columns=['class'])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, stratify = y, random_state=42)

parameters = {'n_estimators': 100, 'max_depth': 5}
model = RandomForestClassifier(**parameters)
model.fit(X_train, y_train)
prediction = model.predict(X_test)
metrics = {
    'accuracy': round(accuracy_score(y_test, prediction), 3),
    'precision': round(precision_score(y_test, prediction, average='macro'), 3),
    'recall': round(recall_score(y_test, prediction, average='macro'), 3),
    'f1': round(f1_score(y_test, prediction, average='macro'), 3)
}

filename='../test_files/rf_iris.pkl'
with open(filename, "wb") as f:
    pickle.dump(model, f)

# %%
with start_iteration(iteration_name='RF model v1') as iteration:
    iteration.log_parameters(parameters=parameters)
    iteration.log_metrics(metrics=metrics)
    iteration.log_path_to_model(path_to_model=os.path.abspath(filename))

# %% [markdown]
# ## Valid prediction

# %%
X_test
# Out:
#      sepal-length  sepal-width  petal-length  petal-width
# 21            5.1          3.7           1.5          0.4
# 7             5.0          3.4           1.5          0.2
# 35            5.0          3.2           1.2          0.2
# 23            5.1          3.3           1.7          0.5
# 132           6.4          2.8           5.6          2.2
# ..            ...          ...           ...          ...
# 53            5.5          2.3           4.0          1.3
# 22            4.6          3.6           1.0          0.2
# 102           7.1          3.0           5.9          2.1
# 136           6.3          3.4           5.6          2.4
# 138           6.0          3.0           4.8          1.8
#
# [75 rows x 4 columns]

# %%
send_prediction(
    model_name='Demo presentation',
    data=X_test
)
# Out:
# [{'id': '655660868621432f52372b9c',
#   'prediction_date': '2023-11-16T19:33:42.112565',
#   'input_data': {'sepal-length': 5.1,
#    'sepal-width': 3.7,
#    'petal-length': 1.5,
#    'petal-width': 0.4},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372b9d',
#   'prediction_date': '2023-11-16T19:33:42.118564',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 3.4,
#    'petal-length': 1.5,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372b9e',
#   'prediction_date': '2023-11-16T19:33:42.125563',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 3.2,
#    'petal-length': 1.2,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372b9f',
#   'prediction_date': '2023-11-16T19:33:42.132075',
#   'input_data': {'sepal-length': 5.1,
#    'sepal-width': 3.3,
#    'petal-length': 1.7,
#    'petal-width': 0.5},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba0',
#   'prediction_date': '2023-11-16T19:33:42.139074',
#   'input_data': {'sepal-length': 6.4,
#    'sepal-width': 2.8,
#    'petal-length': 5.6,
#    'petal-width': 2.2},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba1',
#   'prediction_date': '2023-11-16T19:33:42.144583',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 3.5,
#    'petal-length': 1.3,
#    'petal-width': 0.3},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba2',
#   'prediction_date': '2023-11-16T19:33:42.151192',
#   'input_data': {'sepal-length': 6.6,
#    'sepal-width': 3.0,
#    'petal-length': 4.4,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba3',
#   'prediction_date': '2023-11-16T19:33:42.158093',
#   'input_data': {'sepal-length': 5.6,
#    'sepal-width': 2.8,
#    'petal-length': 4.9,
#    'petal-width': 2.0},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba4',
#   'prediction_date': '2023-11-16T19:33:42.164601',
#   'input_data': {'sepal-length': 4.9,
#    'sepal-width': 2.4,
#    'petal-length': 3.3,
#    'petal-width': 1.0},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba5',
#   'prediction_date': '2023-11-16T19:33:42.170601',
#   'input_data': {'sepal-length': 7.4,
#    'sepal-width': 2.8,
#    'petal-length': 6.1,
#    'petal-width': 1.9},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba6',
#   'prediction_date': '2023-11-16T19:33:42.178112',
#   'input_data': {'sepal-length': 5.6,
#    'sepal-width': 2.5,
#    'petal-length': 3.9,
#    'petal-width': 1.1},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba7',
#   'prediction_date': '2023-11-16T19:33:42.185621',
#   'input_data': {'sepal-length': 4.4,
#    'sepal-width': 3.2,
#    'petal-length': 1.3,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba8',
#   'prediction_date': '2023-11-16T19:33:42.192131',
#   'input_data': {'sepal-length': 5.2,
#    'sepal-width': 2.7,
#    'petal-length': 3.9,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372ba9',
#   'prediction_date': '2023-11-16T19:33:42.199132',
#   'input_data': {'sepal-length': 6.4,
#    'sepal-width': 3.2,
#    'petal-length': 4.5,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372baa',
#   'prediction_date': '2023-11-16T19:33:42.205131',
#   'input_data': {'sepal-length': 4.7,
#    'sepal-width': 3.2,
#    'petal-length': 1.6,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bab',
#   'prediction_date': '2023-11-16T19:33:42.212641',
#   'input_data': {'sepal-length': 5.5,
#    'sepal-width': 4.2,
#    'petal-length': 1.4,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bac',
#   'prediction_date': '2023-11-16T19:33:42.219145',
#   'input_data': {'sepal-length': 5.5,
#    'sepal-width': 3.5,
#    'petal-length': 1.3,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bad',
#   'prediction_date': '2023-11-16T19:33:42.227150',
#   'input_data': {'sepal-length': 6.5,
#    'sepal-width': 3.0,
#    'petal-length': 5.2,
#    'petal-width': 2.0},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bae',
#   'prediction_date': '2023-11-16T19:33:42.234660',
#   'input_data': {'sepal-length': 6.3,
#    'sepal-width': 3.3,
#    'petal-length': 4.7,
#    'petal-width': 1.6},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372baf',
#   'prediction_date': '2023-11-16T19:33:42.242168',
#   'input_data': {'sepal-length': 6.0,
#    'sepal-width': 2.9,
#    'petal-length': 4.5,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb0',
#   'prediction_date': '2023-11-16T19:33:42.249168',
#   'input_data': {'sepal-length': 6.1,
#    'sepal-width': 2.6,
#    'petal-length': 5.6,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb1',
#   'prediction_date': '2023-11-16T19:33:42.257678',
#   'input_data': {'sepal-length': 6.3,
#    'sepal-width': 2.8,
#    'petal-length': 5.1,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb2',
#   'prediction_date': '2023-11-16T19:33:42.264749',
#   'input_data': {'sepal-length': 6.5,
#    'sepal-width': 3.0,
#    'petal-length': 5.8,
#    'petal-width': 2.2},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb3',
#   'prediction_date': '2023-11-16T19:33:42.272254',
#   'input_data': {'sepal-length': 6.2,
#    'sepal-width': 2.9,
#    'petal-length': 4.3,
#    'petal-width': 1.3},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb4',
#   'prediction_date': '2023-11-16T19:33:42.279262',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.3,
#    'petal-length': 5.7,
#    'petal-width': 2.5},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb5',
#   'prediction_date': '2023-11-16T19:33:42.287773',
#   'input_data': {'sepal-length': 6.3,
#    'sepal-width': 2.7,
#    'petal-length': 4.9,
#    'petal-width': 1.8},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb6',
#   'prediction_date': '2023-11-16T19:33:42.297419',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 2.3,
#    'petal-length': 3.3,
#    'petal-width': 1.0},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb7',
#   'prediction_date': '2023-11-16T19:33:42.305929',
#   'input_data': {'sepal-length': 4.9,
#    'sepal-width': 3.0,
#    'petal-length': 1.4,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb8',
#   'prediction_date': '2023-11-16T19:33:42.313433',
#   'input_data': {'sepal-length': 5.4,
#    'sepal-width': 3.0,
#    'petal-length': 4.5,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bb9',
#   'prediction_date': '2023-11-16T19:33:42.322438',
#   'input_data': {'sepal-length': 5.5,
#    'sepal-width': 2.6,
#    'petal-length': 4.4,
#    'petal-width': 1.2},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bba',
#   'prediction_date': '2023-11-16T19:33:42.330947',
#   'input_data': {'sepal-length': 7.3,
#    'sepal-width': 2.9,
#    'petal-length': 6.3,
#    'petal-width': 1.8},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bbb',
#   'prediction_date': '2023-11-16T19:33:42.338457',
#   'input_data': {'sepal-length': 5.4,
#    'sepal-width': 3.9,
#    'petal-length': 1.7,
#    'petal-width': 0.4},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bbc',
#   'prediction_date': '2023-11-16T19:33:42.346960',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 3.5,
#    'petal-length': 1.6,
#    'petal-width': 0.6},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bbd',
#   'prediction_date': '2023-11-16T19:33:42.355582',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.0,
#    'petal-length': 5.0,
#    'petal-width': 1.7},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bbe',
#   'prediction_date': '2023-11-16T19:33:42.363472',
#   'input_data': {'sepal-length': 5.1,
#    'sepal-width': 3.8,
#    'petal-length': 1.9,
#    'petal-width': 0.4},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bbf',
#   'prediction_date': '2023-11-16T19:33:42.371981',
#   'input_data': {'sepal-length': 6.4,
#    'sepal-width': 2.7,
#    'petal-length': 5.3,
#    'petal-width': 1.9},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc0',
#   'prediction_date': '2023-11-16T19:33:42.381488',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.1,
#    'petal-length': 5.6,
#    'petal-width': 2.4},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc1',
#   'prediction_date': '2023-11-16T19:33:42.389998',
#   'input_data': {'sepal-length': 6.4,
#    'sepal-width': 3.1,
#    'petal-length': 5.5,
#    'petal-width': 1.8},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc2',
#   'prediction_date': '2023-11-16T19:33:42.398013',
#   'input_data': {'sepal-length': 6.3,
#    'sepal-width': 2.3,
#    'petal-length': 4.4,
#    'petal-width': 1.3},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc3',
#   'prediction_date': '2023-11-16T19:33:42.407017',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.1,
#    'petal-length': 4.7,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc4',
#   'prediction_date': '2023-11-16T19:33:42.414527',
#   'input_data': {'sepal-length': 5.9,
#    'sepal-width': 3.0,
#    'petal-length': 4.2,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc5',
#   'prediction_date': '2023-11-16T19:33:42.423631',
#   'input_data': {'sepal-length': 5.8,
#    'sepal-width': 4.0,
#    'petal-length': 1.2,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc6',
#   'prediction_date': '2023-11-16T19:33:42.432143',
#   'input_data': {'sepal-length': 4.4,
#    'sepal-width': 3.0,
#    'petal-length': 1.3,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc7',
#   'prediction_date': '2023-11-16T19:33:42.441653',
#   'input_data': {'sepal-length': 6.1,
#    'sepal-width': 3.0,
#    'petal-length': 4.6,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc8',
#   'prediction_date': '2023-11-16T19:33:42.449654',
#   'input_data': {'sepal-length': 6.5,
#    'sepal-width': 3.0,
#    'petal-length': 5.5,
#    'petal-width': 1.8},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bc9',
#   'prediction_date': '2023-11-16T19:33:42.458848',
#   'input_data': {'sepal-length': 5.1,
#    'sepal-width': 3.5,
#    'petal-length': 1.4,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bca',
#   'prediction_date': '2023-11-16T19:33:42.468358',
#   'input_data': {'sepal-length': 6.6,
#    'sepal-width': 2.9,
#    'petal-length': 4.6,
#    'petal-width': 1.3},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bcb',
#   'prediction_date': '2023-11-16T19:33:42.476870',
#   'input_data': {'sepal-length': 5.7,
#    'sepal-width': 3.8,
#    'petal-length': 1.7,
#    'petal-width': 0.3},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bcc',
#   'prediction_date': '2023-11-16T19:33:42.486385',
#   'input_data': {'sepal-length': 6.0,
#    'sepal-width': 3.4,
#    'petal-length': 4.5,
#    'petal-width': 1.6},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bcd',
#   'prediction_date': '2023-11-16T19:33:42.495411',
#   'input_data': {'sepal-length': 5.6,
#    'sepal-width': 3.0,
#    'petal-length': 4.5,
#    'petal-width': 1.5},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bce',
#   'prediction_date': '2023-11-16T19:33:42.505921',
#   'input_data': {'sepal-length': 5.8,
#    'sepal-width': 2.7,
#    'petal-length': 4.1,
#    'petal-width': 1.0},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bcf',
#   'prediction_date': '2023-11-16T19:33:42.515431',
#   'input_data': {'sepal-length': 6.1,
#    'sepal-width': 2.9,
#    'petal-length': 4.7,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd0',
#   'prediction_date': '2023-11-16T19:33:42.524940',
#   'input_data': {'sepal-length': 6.2,
#    'sepal-width': 2.8,
#    'petal-length': 4.8,
#    'petal-width': 1.8},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd1',
#   'prediction_date': '2023-11-16T19:33:42.535451',
#   'input_data': {'sepal-length': 4.8,
#    'sepal-width': 3.4,
#    'petal-length': 1.6,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd2',
#   'prediction_date': '2023-11-16T19:33:42.544960',
#   'input_data': {'sepal-length': 5.1,
#    'sepal-width': 2.5,
#    'petal-length': 3.0,
#    'petal-width': 1.1},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd3',
#   'prediction_date': '2023-11-16T19:33:42.555475',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 2.5,
#    'petal-length': 5.8,
#    'petal-width': 1.8},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd4',
#   'prediction_date': '2023-11-16T19:33:42.564978',
#   'input_data': {'sepal-length': 6.2,
#    'sepal-width': 3.4,
#    'petal-length': 5.4,
#    'petal-width': 2.3},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd5',
#   'prediction_date': '2023-11-16T19:33:42.575621',
#   'input_data': {'sepal-length': 4.9,
#    'sepal-width': 2.5,
#    'petal-length': 4.5,
#    'petal-width': 1.7},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd6',
#   'prediction_date': '2023-11-16T19:33:42.586001',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.1,
#    'petal-length': 4.4,
#    'petal-width': 1.4},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd7',
#   'prediction_date': '2023-11-16T19:33:42.596021',
#   'input_data': {'sepal-length': 5.0,
#    'sepal-width': 3.3,
#    'petal-length': 1.4,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd8',
#   'prediction_date': '2023-11-16T19:33:42.605027',
#   'input_data': {'sepal-length': 5.7,
#    'sepal-width': 2.8,
#    'petal-length': 4.5,
#    'petal-width': 1.3},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bd9',
#   'prediction_date': '2023-11-16T19:33:42.615535',
#   'input_data': {'sepal-length': 6.1,
#    'sepal-width': 3.0,
#    'petal-length': 4.9,
#    'petal-width': 1.8},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372bda',
#   'prediction_date': '2023-11-16T19:33:42.627124',
#   'input_data': {'sepal-length': 6.7,
#    'sepal-width': 3.0,
#    'petal-length': 5.2,
#    'petal-width': 2.3},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bdb',
#   'prediction_date': '2023-11-16T19:33:42.637719',
#   'input_data': {'sepal-length': 5.4,
#    'sepal-width': 3.4,
#    'petal-length': 1.7,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bdc',
#   'prediction_date': '2023-11-16T19:33:42.648146',
#   'input_data': {'sepal-length': 5.2,
#    'sepal-width': 3.5,
#    'petal-length': 1.5,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bdd',
#   'prediction_date': '2023-11-16T19:33:42.658655',
#   'input_data': {'sepal-length': 7.7,
#    'sepal-width': 2.8,
#    'petal-length': 6.7,
#    'petal-width': 2.0},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372bde',
#   'prediction_date': '2023-11-16T19:33:42.669236',
#   'input_data': {'sepal-length': 5.4,
#    'sepal-width': 3.7,
#    'petal-length': 1.5,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372bdf',
#   'prediction_date': '2023-11-16T19:33:42.680321',
#   'input_data': {'sepal-length': 4.7,
#    'sepal-width': 3.2,
#    'petal-length': 1.3,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372be0',
#   'prediction_date': '2023-11-16T19:33:42.690832',
#   'input_data': {'sepal-length': 6.9,
#    'sepal-width': 3.1,
#    'petal-length': 5.1,
#    'petal-width': 2.3},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372be1',
#   'prediction_date': '2023-11-16T19:33:42.702343',
#   'input_data': {'sepal-length': 5.2,
#    'sepal-width': 3.4,
#    'petal-length': 1.4,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372be2',
#   'prediction_date': '2023-11-16T19:33:42.712852',
#   'input_data': {'sepal-length': 5.5,
#    'sepal-width': 2.3,
#    'petal-length': 4.0,
#    'petal-width': 1.3},
#   'prediction': 1.0,
#   'actual': None},
#  {'id': '655660868621432f52372be3',
#   'prediction_date': '2023-11-16T19:33:42.723361',
#   'input_data': {'sepal-length': 4.6,
#    'sepal-width': 3.6,
#    'petal-length': 1.0,
#    'petal-width': 0.2},
#   'prediction': 0.0,
#   'actual': None},
#  {'id': '655660868621432f52372be4',
#   'prediction_date': '2023-11-16T19:33:42.734871',
#   'input_data': {'sepal-length': 7.1,
#    'sepal-width': 3.0,
#    'petal-length': 5.9,
#    'petal-width': 2.1},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372be5',
#   'prediction_date': '2023-11-16T19:33:42.746382',
#   'input_data': {'sepal-length': 6.3,
#    'sepal-width': 3.4,
#    'petal-length': 5.6,
#    'petal-width': 2.4},
#   'prediction': 2.0,
#   'actual': None},
#  {'id': '655660868621432f52372be6',
#   'prediction_date': '2023-11-16T19:33:42.756890',
#   'input_data': {'sepal-length': 6.0,
#    'sepal-width': 3.0,
#    'petal-length': 4.8,
#    'petal-width': 1.8},
#   'prediction': 1.0,
#   'actual': None}]

# %%
pd.DataFrame(get_model_by_name(model_name='Demo presentation')['predictions_data'])
# Out:
#                           id             prediction_date  \
# 0   655660868621432f52372b9c  2023-11-16T19:33:42.112000
# 1   655660868621432f52372b9d  2023-11-16T19:33:42.118000
# 2   655660868621432f52372b9e  2023-11-16T19:33:42.125000
# 3   655660868621432f52372b9f  2023-11-16T19:33:42.132000
# 4   655660868621432f52372ba0  2023-11-16T19:33:42.139000
# ..                       ...                         ...
# 70  655660868621432f52372be2  2023-11-16T19:33:42.712000
# 71  655660868621432f52372be3  2023-11-16T19:33:42.723000
# 72  655660868621432f52372be4  2023-11-16T19:33:42.734000
# 73  655660868621432f52372be5  2023-11-16T19:33:42.746000
# 74  655660868621432f52372be6  2023-11-16T19:33:42.756000
#
#                                            input_data  prediction  actual
# 0   {'sepal-length': 5.1, 'sepal-width': 3.7, 'pet...         0.0     NaN
# 1   {'sepal-length': 5.0, 'sepal-width': 3.4, 'pet...         0.0     NaN
# 2   {'sepal-length': 5.0, 'sepal-width': 3.2, 'pet...         0.0     NaN
# 3   {'sepal-length': 5.1, 'sepal-width': 3.3, 'pet...         0.0     NaN
# 4   {'sepal-length': 6.4, 'sepal-width': 2.8, 'pet...         2.0     NaN
# ..                                                ...         ...     ...
# 70  {'sepal-length': 5.5, 'sepal-width': 2.3, 'pet...         1.0     1.0
# 71  {'sepal-length': 4.6, 'sepal-width': 3.6, 'pet...         0.0     0.0
# 72  {'sepal-length': 7.1, 'sepal-width': 3.0, 'pet...         2.0     2.0
# 73  {'sepal-length': 6.3, 'sepal-width': 3.4, 'pet...         2.0     2.0
# 74  {'sepal-length': 6.0, 'sepal-width': 3.0, 'pet...         1.0     1.0
#
# [75 rows x 5 columns]

# %% [markdown]
# ## Invalid prediction (wrong column names)

# %%
send_prediction(
    model_name='Demo presentation',
    data=pd.DataFrame({'X1': [121], 'X2': [3]})
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27076/1020207993.py in <module>
# ----> 1 send_prediction(
#       2     model_name='Demo presentation',
#       3     data=pd.DataFrame({'X1': [121], 'X2': [3]})
#       4 )
#
# C:\mlops-inzynierka\library\tests\notebooks\../..\mlops\monitoring.py in send_prediction(model_name, data)
#     100         return prediction
#     101     else:
# --> 102         raise request_failed_exception(app_response)
#
# Exception: Request failed with status code 400: Cannot make prediction: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - X1
# - X2
# Feature names seen at fit time, yet now missing:
# - petal-length
# - petal-width
# - sepal-length
# - sepal-width

# %% [markdown]
# ## Invalid prediction (wrong value type)

# %%
send_prediction(
    model_name='Demo presentation',
    data=pd.DataFrame({
        'sepal-length': ['WRONG value'],
        'sepal-width': [2.8],
        'petal-length': [4.9],
        'petal-width': [2.0]
    })
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27076/1255930564.py in <module>
# ----> 1 send_prediction(
#       2     model_name='Demo presentation',
#       3     data=pd.DataFrame({
#       4         'sepal-length': ['WRONG value'],
#       5         'sepal-width': [2.8],
#
# C:\mlops-inzynierka\library\tests\notebooks\../..\mlops\monitoring.py in send_prediction(model_name, data)
#     100         return prediction
#     101     else:
# --> 102         raise request_failed_exception(app_response)
#
# Exception: Request failed with status code 400: Cannot make prediction: could not convert string to float: 'WRONG value'

# %% [markdown]
# ## Invalid + valid together

# %%
send_prediction(
    model_name='Demo presentation',
    data=pd.DataFrame({
        'sepal-length': [1.0, 'WRONG value'],
        'sepal-width': [1.0, 1.0],
        'petal-length': [1.0, 1.0],
        'petal-width': [1.0, 1.0]
    })
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27076/3413441724.py in <module>
# ----> 1 send_prediction(
#       2     model_name='Demo presentation',
#       3     data=pd.DataFrame({
#       4         'sepal-length': [1.0, 'WRONG value'],
#       5         'sepal-width': [1.0, 1.0],
#
# C:\mlops-inzynierka\library\tests\notebooks\../..\mlops\monitoring.py in send_prediction(model_name, data)
#     100         return prediction
#     101     else:
# --> 102         raise request_failed_exception(app_response)
#
# Exception: Request failed with status code 400: Cannot make prediction: could not convert string to float: 'WRONG value'
